# %%
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
library = pd.read_excel('./데이터 분석과 통계/지역별 도서관 수_2008-2023.xlsx')
library
# Out:
#       시점    전국  수도권(서울+경기+인천)   서울   경기  인천  비수도권  부산  대구  광주  ...  울산  세종  \
# 0   2008   644            225   78  130  17   419  24  18  16  ...   9   -
# 1   2009   703            261   94  143  24   442  27  20  16  ...   9   -
# 2   2010   759            290  101  163  26   469  30  26  16  ...  11   -
# 3   2011   786            309  109  169  31   477  31  27  16  ...  11   -
# 4   2012   828            336  116  184  36   492  31  27  17  ...  12   1
# 5   2013   865            356  123  194  39   509  31  28  17  ...  13   1
# 6   2014   930            391  132  217  42   539  32  30  20  ...  17   3
# 7   2015   978            420  146  228  46   558  36  33  21  ...  17   4
# 8   2016  1010            438  147  244  47   572  40  35  22  ...  17   5
# 9   2017  1042            458  160  250  48   584  40  36  23  ...  18   5
# 10  2018  1096            487  173  264  50   609  43  41  23  ...  19  10
# ...

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# # 1번 데이터 준비
# data1 = {
#     "서울": [27730, 1699164, 2218418, 2719256, 3483010, 3272774, 7673348, 3921423, 5485548, 11352342, 12829455, 13454736],
#     "경기": [0, 64, 17659, 23557, 289633, 192924, 860615, 183381, 657392, 1752374, 2000581, 2560279],
#     "인천": [0, 0, 8180, 11673, 28098, 14024, 239514, 35718, 111800, 469948, 592631, 823965]
# }

# # 1번 데이터프레임 생성
# years = np.arange(2013, 2025)  # 연도를 숫자로 변환
# df1 = pd.DataFrame(data1, index=years)

# # 1번 수도권 데이터 합치기
# df1['서울_경기_인천'] = df1['서울'] + df1['경기'] + df1['인천']

# # 2번 데이터 준비
# data2 = {
#     '서울': [-100550, -87831, -137256, -140257, -98486, -110230, -49588, -64850, -106243, -35340, -31250, -44692],
#     '경기': [74131, 57396, 94768, 133617, 116162, 170094, 134666, 168373, 150517, 43882, 44612, 64218],
#     '인천': [22035, 9324, 9538, 5777, -1670, -67, -2337, -15748, 11423, 28101, 33507, 25643]
# }

# # 2번 데이터프레임 생성
# df2 = pd.DataFrame(data2, index=years)

# # 2번 수도권 데이터 합치기
# df2['서울_인천_경기'] = df2['서울'] + df2['인천'] + df2['경기']

# # 상관관계 계산
# correlation = df1['서울_경기_인천'].corr(df2['서울_인천_경기'])
# print(f"수도권(서울, 경기, 인천) 총 티켓 판매 수와 순이동 수의 상관계수: {correlation}")

# # 그래프 그리기
# fig, ax1 = plt.subplots(figsize=(14, 8))

# # 총 티켓 판매 수 (왼쪽 y축)
# ax1.plot(years, df1['서울_경기_인천'], color='b', marker='o', label='수도권 총 티켓 판매 수', linestyle='-')
# ax1.set_xlabel('연도', fontsize=12)
# ax1.set_ylabel('총 티켓 판매 수 [건]\n1e7=10,000,000', fontsize=12, color='b')
# ax1.tick_params(axis='y', labelcolor='b')

# # 총 티켓 판매 수 추세선 추가
# z1 = np.polyfit(years, df1['서울_경기_인천'], 1)  # 1차 다항식(선형 회귀)
# p1 = np.poly1d(z1)
# ax1.plot(years, p1(years), color='skyblue', linestyle='dotted', label='티켓 판매 수 추세선')

# # 순이동 수 (오른쪽 y축)
# ax2 = ax1.twinx()
# ax2.plot(years, df2['서울_인천_경기'], color='r', marker='s', label='수도권 순이동 수', linestyle='--')
# ax2.set_ylabel('순이동 수 [명]', fontsize=12, color='r')
# ax2.tick_params(axis='y', labelcolor='r')

# # 순이동 수 추세선 추가
# z2 = np.polyfit(years, df2['서울_인천_경기'], 1)  # 1차 다항식(선형 회귀)
# p2 = np.poly1d(z2)
# ax2.plot(years, p2(years), color='orange', linestyle='dotted', label='순이동 수 추세선')

# # 범례 추가
# ax1.legend(loc='upper left')  # 왼쪽 y축 범례
# ax2.legend(loc='upper right')  # 오른쪽 y축 범례

# # 제목 및 레이아웃 설정
# plt.title('수도권(서울, 경기, 인천)의 총 티켓 판매 수와 순이동 수 비교 (2013~2024)', fontsize=16)
# plt.grid()
# fig.tight_layout()
# plt.show()

# %%
plt.plot(library['시점'], library['수도권(서울+경기+인천)'], label='수도권(서울+경기+인천)', marker='o')
plt.plot(library['시점'], library['비수도권'], label='비수도권', marker='o')
plt.title('공공도서관 수')
plt.grid()
plt.legend()
plt.show()

# %%
library_subtract = pd.read_excel('./데이터 분석과 통계/지역별 도서관 수_전년 대비 증가 수_2008-2023.xlsx')
library_subtract
# Out:
#       시점    전국  전국 전년대비 증가  수도권(서울+경기+인천)  수도권 전년대비 증가   서울   경기  인천  비수도권  \
# 0   2008   644         NaN            225            0   78  130  17   419
# 1   2009   703        59.0            261           36   94  143  24   442
# 2   2010   759        56.0            290           29  101  163  26   469
# 3   2011   786        27.0            309           19  109  169  31   477
# 4   2012   828        42.0            336           27  116  184  36   492
# 5   2013   865        37.0            356           20  123  194  39   509
# 6   2014   930        65.0            391           35  132  217  42   539
# 7   2015   978        48.0            420           29  146  228  46   558
# 8   2016  1010        32.0            438           18  147  244  47   572
# 9   2017  1042        32.0            458           20  160  250  48   584
# 10  2018  1096        54.0            487           29  173  264  50   609
# ...

# %%
library_subtract = library_subtract.drop(0)

# %%
plt.plot(library_subtract['시점'], library_subtract['수도권 전년대비 증가'], label='수도권 전년대비 증가')
plt.plot(library_subtract['시점'], library_subtract['비수도권 전년대비 증가'], label='비수도권 전년대비 증가')

plt.title('전년대비 도서관 증가 수')
plt.xticks(library_subtract['시점'][::2])
plt.grid()
plt.legend()
plt.show()

# %%
library_budget = pd.read_excel('./데이터 분석과 통계/지역별도서관 총 결산 예산액(백만원)_2007-2023.xlsx')
library_budget
# Out:
#       시점       전국  수도권(서울+경기+인천)      서울      경기     인천    비수도권     부산     대구  \
# 0   2007   417438         175792   60010  100477  15305  241646  24424  21237
# 1   2008   482242         221901   65531  139579  16791  260342  26634  23706
# 2   2009   605976         285817   75761  182533  27523  320159  29580  24324
# 3   2010   610044         284921   85255  170718  28948  325125  27171  23962
# 4   2011   609283         287576   76070  184171  27335  321707  31081  24793
# 5   2012   694244         334682   82249  221097  31336  359563  38265  21207
# 6   2013   744953         364591   88070  245802  30719  380359  35577  26983
# 7   2014   732512         328663   87555  208888  32220  403849  51643  27587
# 8   2015   825093         382803  111811  231660  39332  442291  40889  28590
# 9   2016   908448         435409  125674  266848  42887  473039  50469  30176
# 10  2017   995584         489259  163396  278143  47720  506325  43068  32367
# ...

# %%
plt.plot(library_budget['시점'], library_budget['수도권(서울+경기+인천)'], label='수도권')
plt.plot(library_budget['시점'], library_budget['비수도권'], label='비수도권')

plt.title('도서관 총 결산 예산액(백만원)')
plt.xticks(library_budget['시점'][::2])
plt.grid()
plt.legend()
plt.show()

# %%
library_budget_per_branch = pd.read_excel('./데이터 분석과 통계/지역별도서관 1관당 결산 예산액(백만원)_2007-2023.xlsx')
library_budget_per_branch
# Out:
#       시점    전국  수도권(서울+경기+인천)    서울    경기    인천   비수도권    부산    대구    광주  ...  \
# 0   2007   696           2788   909   859  1020   9342  1018  1327  1102  ...
# 1   2008   749           2902   840  1074   988   9169  1110  1317   879  ...
# 2   2009   862           3229   806  1276  1147  10264  1096  1216  1078  ...
# 3   2010   804           3004   844  1047  1113   9591   906   922  1168  ...
# 4   2011   775           2670   698  1090   882   9451  1003   918  1234  ...
# 5   2012   838           2781   709  1202   870  11924  1234   785  1143  ...
# 6   2013   861           2771   716  1267   788  12555  1148   964  1263  ...
# 7   2014   788           2393   663   963   767  11400  1614   920  1313  ...
# 8   2015   844           2637   766  1016   855  11138  1136   866  1230  ...
# 9   2016   899           2861   855  1094   912  11447  1262   862  1178  ...
# 10  2017   955           3128  1021  1113   994  11974  1077   899  1228  ...
# ...

# %%
plt.plot(library_budget_per_branch['시점'], library_budget_per_branch['수도권(서울+경기+인천)'], label='수도권')
plt.plot(library_budget_per_branch['시점'], library_budget_per_branch['비수도권'], label='비수도권')

plt.title('도서관 1관당 결산 예산액(백만원)')
plt.xticks(library_budget_per_branch['시점'][::2])
plt.grid()
plt.legend()
plt.show()

# %%
library_visitor_count = pd.read_excel('./데이터 분석과 통계/지역별도서관 총 방문자 수_2007-2023.xlsx')
library_visitor_count
# Out:
#       시점         전국  수도권(서울+경기+인천)        서울        경기        인천       비수도권  \
# 0   2008  204919424      109345480  43850941  55696877   9797662   95573944
# 1   2009  235211876      130282986  49231515  69995237  11056234  104928890
# 2   2010  258315524      145751478  53642006  79457939  12651533  112564046
# 3   2011  270480202      151423577  57095987  82202919  12124671  119056625
# 4   2012  285408417      158217928  60377702  84735991  13104235  127190489
# 5   2013  287018433      163311760  64286726  84308425  14716609  123706673
# 6   2014  290607536      163284056  71043565  77584847  14655644  127323480
# 7   2015  281672237      154370399  71050641  69517314  13802444  127301838
# 8   2016  282040395      159082839  68247780  76890677  13944382  122957556
# 9   2017  272068981      153699105  64248566  75185228  14265311  118369876
# 10  2018  277797323      156894541  66955435  75961301  13977805  120902782
# ...

# %%
plt.plot(library_visitor_count['시점'], library_visitor_count['수도권(서울+경기+인천)'], label='수도권')
plt.plot(library_visitor_count['시점'], library_visitor_count['비수도권'], label='비수도권')

plt.title('도서관 총 방문자 수')
plt.xticks(library_visitor_count['시점'][::2])
plt.grid()
plt.legend()
plt.show()

# %%
visitor_count_per_branch = pd.read_excel('./데이터 분석과 통계/지역별도서관 1관당 방문자 수_2007-2023.xlsx')
visitor_count_per_branch
# Out:
#       시점      전국  수도권(서울+경기+인천)      서울      경기      인천     비수도권      부산  \
# 0   2008  318198        1566963  562192  428438  576333  3600538  560767
# 1   2009  334583        1473893  523740  489477  460676  3720399  475817
# 2   2010  340337        1505178  531109  487472  486597  3584022  537013
# 3   2011  344122        1401342  523816  486408  391118  3792300  596684
# 4   2012  344696        1345026  520497  460522  364007  3902514  581723
# 5   2013  331813        1334585  522656  434580  377349  3753092  580875
# 6   2014  312481        1244687  538209  357534  348944  3515411  574785
# 7   2015  288008        1091602  486648  304901  300053  3375944  500235
# 8   2016  279248        1076086  464271  315126  296689  3185882  434931
# 9   2017  261103         999489  401554  300741  297194  2970596  412363
# 10  2018  253864         954314  387026  287732  279556  2927697  375313
# 11  2019  250804         959186  371823  285473  301890  2923650  352960
# ...

# %%
plt.plot(visitor_count_per_branch['시점'], visitor_count_per_branch['수도권(서울+경기+인천)'], label='수도권')
plt.plot(visitor_count_per_branch['시점'], visitor_count_per_branch['비수도권'], label='비수도권')

plt.title('도서관 1관당 방문자 수')
plt.xticks(visitor_count_per_branch['시점'][::2])
plt.grid()
plt.legend()
plt.show()

# %%
library_staff_count = pd.read_excel('./데이터 분석과 통계/지역별도서관 직원 수(명)_2007-2023.xlsx')
library_staff_count
# Out:
#       시점       전국  수도권(서울+경기+인천)      서울      경기      인천    비수도권     부산  \
# 0   2008   8905.0         3837.0  1468.0  2017.0   352.0  5068.0  541.0
# 1   2009  10524.0         5011.0  1740.0  2811.0   460.0  5513.0  625.0
# 2   2010  11090.0         5316.0  1802.0  3044.0   470.0  5774.0  680.0
# 3   2011  11641.0         5639.0  1785.0  3322.0   532.0  6002.0  651.0
# 4   2012  12489.0         6187.0  1866.0  3737.0   584.0  6302.0  651.0
# 5   2013  13061.0         6610.0  1995.0  3983.0   632.0  6451.0  646.0
# 6   2014  13936.0         7042.0  2082.0  4247.0   713.0  6894.0  666.0
# 7   2015  14411.0         7473.0  2192.0  4535.0   746.0  6938.0  679.0
# 8   2016  15192.0         7956.0  2281.0  4894.0   781.0  7236.0  704.0
# 9   2017  15557.0         8162.0  2449.0  4921.0   792.0  7395.0  682.0
# 10  2018  16576.0         8705.0  2600.0  5218.0   887.0  7871.0  691.0
# 11  2019  17557.0         9196.0  2781.5  5494.0   920.5  8361.0  743.5
# ...

# %%
plt.plot(library_staff_count['시점'], library_staff_count['수도권(서울+경기+인천)'], label='수도권')
plt.plot(library_staff_count['시점'], library_staff_count['비수도권'], label='비수도권')

plt.title('도서관 직원 수')
plt.xticks(library_staff_count['시점'][::2])
plt.grid()
plt.legend()
plt.show()

# %%
library_staff_count_per_branch = pd.read_excel('./데이터 분석과 통계/지역별도서관 1관당 직원 수(명)_2007-2023.xlsx')
library_staff_count_per_branch
# Out:
#       시점    전국  수도권(서울+경기+인천)    서울    경기    인천   비수도권    부산    대구    광주  ...  \
# 0   2008  13.8           55.0  18.8  15.5  20.7  180.0  22.5  19.8  21.0  ...
# 1   2009  15.0           57.4  18.5  19.7  19.2  184.9  23.1  19.6  23.5  ...
# 2   2010  14.6           54.6  17.8  18.7  18.1  178.1  22.7  15.9  23.4  ...
# 3   2011  14.8           53.3  16.4  19.7  17.2  178.5  21.0  16.3  21.2  ...
# 4   2012  15.1           52.6  16.1  20.3  16.2  195.7  21.0  16.3  22.2  ...
# 5   2013  15.1           52.9  16.2  20.5  16.2  202.1  20.8  16.9  21.6  ...
# 6   2014  15.0           52.4  15.8  19.6  17.0  188.6  20.8  16.2  20.8  ...
# 7   2015  14.7           51.1  15.0  19.9  16.2  178.7  18.9  15.5  20.2  ...
# 8   2016  15.0           52.2  15.5  20.1  16.6  181.8  17.6  13.8  21.5  ...
# 9   2017  15.0           52.0  15.0  20.0  17.0  180.0  17.0  13.0  20.0  ...
# 10  2018  15.1           52.5  15.0  19.8  17.7  183.4  16.1  13.4  21.1  ...
# ...

# %%
plt.plot(library_staff_count_per_branch['시점'], library_staff_count_per_branch['수도권(서울+경기+인천)'], label='수도권')
plt.plot(library_staff_count_per_branch['시점'], library_staff_count_per_branch['비수도권'], label='비수도권')

plt.title('도서관 1관당 직원 수')
plt.xticks(library_staff_count_per_branch['시점'][::2])
plt.grid()
plt.legend()
plt.show()

# %%
library_user_count = pd.read_excel('./데이터 분석과 통계/지역별도서관 연간 이용자 수_2007-2023.xlsx')
library_user_count
# Out:
#       시점         전국  수도권(서울+경기+인천)        서울        경기        인천      비수도권  \
# 0   2008  136802882       72968722  28498983  37264522   7205217  63834160
# 1   2009  162851171       92621194  33553500  50814031   8253663  70229977
# 2   2010  178051075      102801909  37045407  56399286   9357216  75249166
# 3   2011  187674068      109952341  42552573  58203064   9196704  77721727
# 4   2012  192028784      112086763  41676378  60592347   9818038  79942021
# 5   2013  200125561      119885672  47072804  61892563  10920305  80239889
# 6   2014  194571747      114014136  46143554  56129492  11741090  80557611
# 7   2015  194425423      114910317  48719001  55959946  10231370  79515106
# 8   2016  195051951      118200895  50698340  56607827  10894728  76851056
# 9   2017  191187830      117613676  48554365  57901379  11157932  73574154
# 10  2018  195570103      119523050  51070334  57854724  10597992  76047053
# ...

# %%
plt.plot(library_user_count['시점'], library_user_count['수도권(서울+경기+인천)'], label='수도권')
plt.plot(library_user_count['시점'], library_user_count['비수도권'], label='비수도권')

plt.title('도서관 이용자 수(명)')
plt.xticks(library_user_count['시점'][::1])
plt.grid()
plt.legend()
plt.show()

# %%
count_of_librarian_certificates = pd.read_excel('./데이터 분석과 통계/지역별도서관 사서자격증 보유자(명)_2007-2023.xlsx')
count_of_librarian_certificates
# Out:
#       시점    전국  수도권(서울+경기+인천)    서울    경기   인천  비수도권   부산   대구   광주  ...   울산  \
# 0   2007  3251           1560   739   662  159  1691  212  142  101  ...   61
# 1   2008  3433           1626   706   749  171  1807  230  144   99  ...   65
# 2   2009  3811           1878   827   832  219  1933  258  156  103  ...   68
# 3   2010  4013           1949   875   855  219  2064  279  182  103  ...   76
# 4   2011  4147           2038   909   876  253  2109  276  194  100  ...   74
# 5   2012  4317           2146   938   950  258  2171  282  204  109  ...   76
# 6   2013  4586           2313  1005  1032  276  2273  300  227  119  ...   88
# 7   2014  4975           2558  1107  1140  311  2417  326  245  126  ...   92
# 8   2015  5370           2759  1212  1223  324  2611  367  258  136  ...  105
# 9   2016  5710           2972  1283  1351  338  2738  378  260  140  ...  107
# 10  2017  6035           3188  1384  1440  364  2847  372  269  144  ...   91
# ...

# %%
plt.plot(count_of_librarian_certificates['시점'], count_of_librarian_certificates['수도권(서울+경기+인천)'], label='수도권')
plt.plot(count_of_librarian_certificates['시점'], count_of_librarian_certificates['비수도권'], label='비수도권')

plt.title('도서관 사서자격증 보유자 수(명)')
plt.xticks(count_of_librarian_certificates['시점'][::2])
plt.grid()
plt.legend()
plt.show()

# %%
librarian_certificate_count_per_branch = pd.read_excel('./데이터 분석과 통계/지역별도서관 1관당 평균 사서자격증 보유자(명)_2007-2023.xlsx')
librarian_certificate_count_per_branch
# Out:
#       시점   전국  수도권(서울+경기+인천)    서울   경기    인천  비수도권    부산   대구   광주  ...   울산  \
# 0   2007  5.4           27.5  11.2  5.7  10.6  66.7   8.8  8.9  7.8  ...  7.6
# 1   2008  5.3           25.0   9.1  5.8  10.1  65.3   9.6  8.0  6.2  ...  7.2
# 2   2009  5.4           23.7   8.8  5.8   9.1  65.7   9.6  7.8  6.4  ...  7.6
# 3   2010  5.3           22.3   8.7  5.2   8.4  63.8   9.3  7.0  6.4  ...  6.9
# 4   2011  5.3           21.7   8.3  5.2   8.2  63.8   8.9  7.2  6.3  ...  6.7
# 5   2012  5.2           20.5   8.1  5.2   7.2  67.6   9.1  7.6  6.4  ...  6.3
# 6   2013  5.3           20.6   8.2  5.3   7.1  72.6   9.7  8.1  7.0  ...  6.8
# 7   2014  5.3           21.1   8.4  5.3   7.4  66.1  10.2  8.2  6.3  ...  5.4
# 8   2015  5.5           20.7   8.3  5.4   7.0  68.6  10.2  7.8  6.5  ...  6.2
# 9   2016  5.7           21.4   8.7  5.5   7.2  70.1   9.5  7.4  6.4  ...  6.3
# 10  2017  6.0           23.0   9.0  6.0   8.0  67.0   9.0  7.0  6.0  ...  5.0
# ...

# %%
plt.plot(librarian_certificate_count_per_branch['시점'], librarian_certificate_count_per_branch['수도권(서울+경기+인천)'], label='수도권')
plt.plot(librarian_certificate_count_per_branch['시점'], librarian_certificate_count_per_branch['비수도권'], label='비수도권')

plt.title('도서관 1관당 사서자격증 보유자 수(명)')
plt.xticks(librarian_certificate_count_per_branch['시점'][::2])
plt.grid()
plt.legend()
plt.show()

# %%
library_total_floor_area = pd.read_excel('./데이터 분석과 통계/지역별도서관 총 연면적(제곱미터)_2007-2023.xlsx')
library_total_floor_area
# Out:
#       시점       전국  수도권(서울+경기+인천)      서울      경기      인천     비수도권      부산  \
# 0   2007  1970000         785000  202000  355000  228000  1185000   76000
# 1   2008  1659000         712000  215000  446000   51000   949000   78000
# 2   2009  1795000         777000  231000  476000   70000  1018000   83000
# 3   2010  1954000         868000  236000  558000   74000  1087000   94000
# 4   2011  1993000         890000  244000  566000   80000  1104000   95000
# 5   2012  2111000         964000  263000  613000   88000  1149000   95000
# 6   2013  2204000        1003000  279000  632000   92000  1202000   96000
# 7   2014  2347000        1098000  290000  711000   97000  1250000  100000
# 8   2015  2465000        1156000  301000  747000  108000  1310000  109000
# 9   2016  2561000        1200000  303000  788000  109000  1361000  114000
# 10  2017  2648000        1254000  331000  811000  112000  1395000  114000
# 11  2018  2791000        1306000  336000  847000  123000  1487000  120000
# ...

# %%
plt.plot(library_total_floor_area['시점'], library_total_floor_area['수도권(서울+경기+인천)'], label='수도권')
plt.plot(library_total_floor_area['시점'], library_total_floor_area['비수도권'], label='비수도권')

plt.title('도서관 총 연면적(m²)')
plt.xticks(library_total_floor_area['시점'][::2])
plt.grid()
plt.legend()
plt.show()

# %%
total_floor_area_per_branch = pd.read_excel('./데이터 분석과 통계/지역별도서관 1관당 평균 연면적(제곱미터)_2007-2023.xlsx')
total_floor_area_per_branch
# Out:
#       시점    전국  수도권(서울+경기+인천)    서울    경기     인천   비수도권    부산    대구    광주  \
# 0   2007  3283          21291  3058  3037  15196  40722  3163  3439  4914
# 1   2008  2576           9163  2754  3428   2981  32291  3257  3201  4101
# 2   2009  2553           8704  2459  3329   2916  32268  3065  3069  4063
# 3   2010  2574           8608  2339  3422   2847  31608  3148  2730  3316
# 4   2011  2536           8167  2239  3347   2581  31444  3062  2631  3370
# 5   2012  2550           8034  2267  3333   2434  32453  3060  2652  3326
# 6   2013  2548           7894  2265  3259   2370  36336  3092  2859  3340
# 7   2014  2524           7776  2195  3276   2305  33522  3115  2732  3599
# 8   2015  2521           7679  2063  3276   2340  33446  3035  2596  3542
# 9   2016  2536           7614  2060  3231   2323  33911  2845  2537  4240
# 10  2017  2542           7650  2066  3244   2340  33821  2845  2511  4153
# 11  2018  2547           7612  1942  3208   2462  34716  2782  2439  4153
# ...

# %%
plt.plot(total_floor_area_per_branch['시점'], total_floor_area_per_branch['수도권(서울+경기+인천)'], label='수도권')
plt.plot(total_floor_area_per_branch['시점'], total_floor_area_per_branch['비수도권'], label='비수도권')

plt.title('도서관 1관당 연면적(m²)')
plt.xticks(total_floor_area_per_branch['시점'][::2])
plt.grid()
plt.legend()
plt.show()

# %%
borrowed_book_count = pd.read_excel('./데이터 분석과 통계/지역별도서관 연간 대출 도서 수_2007-2023.xlsx')
borrowed_book_count
# Out:
#       시점         전국  수도권(서울+경기+인천)        서울        경기       인천      비수도권  \
# 0   2008   93599724       46166974  14660772  27888636  3617566  47432750
# 1   2009  112998355       59478412  18713089  36280697  4484626  53519943
# 2   2010  119074484       63508406  19965666  38532629  5010111  55566078
# 3   2011  124032627       66144553  21517570  39448067  5178916  57888074
# 4   2012  125539467       67643853  21445003  40644166  5554684  57895614
# 5   2013  130886082       70821955  22206149  42826559  5789247  60064127
# 6   2014  137975967       76786578  27006534  43820666  5959378  61189389
# 7   2015  127891750       71237381  24411227  41322804  5503350  56654369
# 8   2016  124121098       69875341  23033500  41696734  5145107  54245757
# 9   2017  126632457       68824346  22662045  41030162  5132139  57808111
# 10  2018  127125318       70724745  23124976  42356906  5242863  56400573
# 11  2019  133769004       74633905  24193256  44827699  5612950  59135099
# ...

# %%
plt.plot(borrowed_book_count['시점'], borrowed_book_count['수도권(서울+경기+인천)'], label='수도권')
plt.plot(borrowed_book_count['시점'], borrowed_book_count['비수도권'], label='비수도권')

plt.title('도서관 대출 도서 수')
plt.xticks(borrowed_book_count['시점'][::2])
plt.grid()
plt.legend()
plt.show()

# %%
library_book_count = pd.read_excel('./데이터 분석과 통계/지역별도서관 전체 도서 종합수_2007-2023.xlsx')
library_book_count
# Out:
#       시점         전국  수도권(서울+경기+인천)        서울         경기       인천       비수도권  \
# 0   2008   57663946       23433812   7117847   14273271  2042694   34230134
# 1   2009   70844323       31390603   8494093   17199684  5696826   39453720
# 2   2010   77078548       34342867  11442518   19223628  3676721   42735681
# 3   2011   78659240       33813712   9936575   21001400  2875737   44845528
# 4   2012  101869627       54216779  14167377   36809893  3239509   47652848
# 5   2013  114224149       63524721  15435360   44545001  3544360   50699428
# 6   2014  107924006       53821507  16263759   33572048  3985700   54102499
# 7   2015  108265241       51276002  17219668   29868343  4187991   56989239
# 8   2016  117321717       57436660  21678858   31355028  4402774   59885057
# 9   2017  130109762       62136341  23489881   33846489  4799971   67973421
# 10  2018  135073495       67409462  24740774   37340629  5328059   67664033
# ...

# %%
plt.plot(library_book_count['시점'], library_book_count['수도권(서울+경기+인천)'], label='수도권')
plt.plot(library_book_count['시점'], library_book_count['비수도권'], label='비수도권')

plt.title('도서관 보유 도서 수')
plt.xticks(library_book_count['시점'][::2])
plt.grid()
plt.legend()
plt.show()
# 23년도에 비약적으로 증대된 이유는 전자자료의 보유 수가 매우 많아졌기 때문이다.

# %%
e_book = pd.read_excel('./데이터 분석과 통계/지역별도서관 총 전자자료 수_2007-2023.xlsx')
e_book
# Out:
#       시점         전국  수도권(서울+경기+인천)        서울         경기       인천       비수도권  \
# 0   2009    5366122        4454627    535366     468683  3450578     911495
# 1   2010    6409222        4456584   2710066     581900  1164618    1952638
# 2   2011    2953911        1562811    597622     876150    89039    1391100
# 3   2012   20322533       18678581   3951264   14626358   100959    1643952
# 4   2013   26697138       24987187   4287080   20577175   122932    1709951
# 5   2014   14347771       11682867   4370229    7103303   209335    2664904
# 6   2015   10514194        7662956   4766043    2712352   184561    2851238
# 7   2016   14537798       11332688   8555650    2582029   195009    3205110
# 8   2017   18740785       13078070   9429470    3289682   358918    5662715
# 9   2018   19483203       14406782   9887190    3921082   598510    5076421
# 10  2019   32614176       27469008  20021212    6821927   625869    5145168
# ...

# %%
plt.plot(e_book['시점'], e_book['수도권(서울+경기+인천)'], label='수도권', marker='.')
plt.plot(e_book['시점'], e_book['비수도권'], label='비수도권', marker='.')

plt.title('도서관 보유 전자자료 수')
plt.xticks(e_book['시점'][::2])
plt.grid()
plt.legend()
plt.show()
